# %%
# import library for handle data
import os
import numpy as np
import pandas as pd
from glob import glob
from matplotlib import pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f6a08d83-0d91-4cb1-863b-9e1a6d61ff05" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f6a08d83-0d91-4cb1-863b-9e1a6d61ff05">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("./")

# %% [markdown]
# ##PCA_model

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd

# create a sample dataset
np.random.seed(123)
df = pd.DataFrame({'feature1': np.random.randn(100),
                   'feature2': np.random.randn(100)})

# Normalize the data using min-max normalization
scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(df)

# Fit k-means clustering on the normalized data
kmeans = KMeans(n_clusters=5, random_state=620)
kmeans.fit(normalized_data)

# Get the cluster labels assigned by k-means
labels = kmeans.labels_

# Perform PCA on the data
pca = PCA(n_components=2)
pca.fit(normalized_data)

# Transform the data to the first two principal components
transformed_data = pca.transform(normalized_data)

# Define a custom color palette with 5 distinct colors
colors = ["#FF0000", "#00FF00", "#0000FF", "#FFDB58", "#FF00FF"]

# Define different marker shapes for each cluster
markers = ["o", "s", "D", "X", "^"]

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))
sns.scatterplot(
    x=transformed_data[:, 0],
    y=transformed_data[:, 1],
    hue=labels,
    palette=colors,
    style=labels,
    markers=markers,
    s=150,
    ax=ax,
)

# Set x and y limits
ax.set_xlim([-0.5, 0.5])
ax.set_ylim([-0.4, 0.5])

# Add a title and axis labels
ax.set_title("PCA with K-Means Clustering")
ax.set_xlabel("First Principal Component")
ax.set_ylabel("Second Principal Component")

# Add a legend outside of the plot
handles, labels = ax.get_legend_handles_labels()
ax.legend(
    handles=handles[1:],  # Exclude the legend title
    labels=["Cluster " + str(i) for i in range(5)],
    loc="center left",
    bbox_to_anchor=(1.05, 0.5),
    borderaxespad=0.0
)

# Plot the elbow plot
inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=100)
    kmeans.fit(normalized_data)
    inertia.append(kmeans.inertia_)
plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), inertia, marker='o')
plt.title('Elbow Plot')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.show()
